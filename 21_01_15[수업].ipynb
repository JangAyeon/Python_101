# %% [markdown]
# <a href="https://colab.research.google.com/github/JangAyeon/Python_Lecture/blob/master/21_01_15%5B%EC%88%98%EC%97%85%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #라이브러리

# %% [markdown]
# *   모듈 : 한 파일로 묶인 변수와 함수의 컬렉션<br>파이썬 소스 파일도 포함<br><br>
# *  모듈 임포트 : 모듈의 변수와 함수에 접근하기 위한 방법<br>import 모듈이름<br><br>
#
#
# *   import 모듈 복구 : <br>쉘 재시작<br>importlib 모듈의 reload 함수 사용
# ```
# import importlib
# importlib.reload(복구할 모듈 이름)
# ```
#
#
# *   파이썬 환경 변수 설정 -> PYTHONPATH 변수에 모듈 디렉토리 추가

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   모듈에 속한 변수 사용<br><모듈이름>.변수명<br><br>
# *   모듈에 속한 함수 사용<br><모듈이름>.함수명(매개변수)<br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   from <모듈명> import <함수명/변수명><br>해당 모듈에 속한 함수명/변수명만 가져옴<br>변수나 함수 사용시 모듈명을 뺀 변수명/함수명으로 사용이 가능<br><br>
# *   from <모듈명> import *<br>해당 모듈에 속한 모든 함수와 변수를 가져옴<br>변수/함수 사용 시 모듈명을 뺀 변수명/함수명으로 사용 가능<br><br>
# *   import <모듈명> as <이름><br>모듈의 이름을 <이름>으로 변경해 사용 가능 <br><br>
# *   from <모듈명> import <함수명 / 변수명> as <이름><br>모듈의 함수명/변수명을 <이름>으로 변경해 사용 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **파이썬 표준 라이브러리**<br>![image.png](data:image/png;base64,...)

# %% [markdown]
# **__main__**<br>
# *   import할 때 실행할 코드 선택 -> "__main__" 이용<br>__main__ : 메인 프로그램<br>특수 문자열 변수 __name__을 이용해 메인 프로그램인지 아닌지 구분 가능<br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# shell 자체에 써서 실행하는 경우 -> main <br>모듈 자체에서 실행하면 main<br>외부에서 모듈을 호출해서 사용 -> main 아님

# %% [markdown]
# **라이브러리 설치**<br>
#
#
# *   pip : 파이썬 패키지 설치 시스템<br><br>
# *  pip : pip 버전 확인<br>커맨드창에 "pip --version"<br><br>
# *   파이썬 라이브러리 설치<br>pip install<라이브러리명>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
